# %% [markdown]
# # **Python Homework #2**

# %%
import numpy as np

# %% [markdown]
# ## Homework Problems

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. Visualize the relationship between pressure and volume for 1.00 mol of He(g) at 298 K in an expandable vessel as it increases from 1 L $\rightarrow$ 20 L. R = 0.08206 L·atm/mol·K.
#
# $$ PV = nRT  $$

# %% [markdown]
# 2. Plot the electronegativity versus atomic number for the first five halogens, and make
# the size or color of the markers based on the atomic radii of the element.
# You will need to look up the values which should be available in most general chemistry textbooks. If you do not have one available, you can also find these values in the free, open chemistry textbook available on OpenStax (https://openstax.org/) among other online resources.

# %% [markdown]
# 3. The following functions are an example of the sandwich theorem which aids in determining limits of function g(x) by knowing its range is between f(x) and h(x) in the relevant domain. Plot all three functions on the same axes to show that f(x) $\leq$ g(x) $\leq$ h(x) for x of -50 $\rightarrow$ 50. Be sure to include a legend.
#
# $$ f(x) = x^2 \quad g(x) = x^2 sin(x) \quad h(x) = -x^2 $$

# %% [markdown]
# 4. Plot the concentration of A with respect to time for the following elementary step if k
# = 0.12 M-1s-1 using the appropriate integrated rate law.
#
# $$ 2 A \rightarrow P $$

# %% [markdown]
# 5. Import the **gc_trace.csv** file containing a gas chromatography (GC) trace and plot the intensity (*y*-axis) versus *m/z* (*x*-axis) using a line plot. Be sure to label the axes.

# %% [markdown]
# 6. Generate an array of atomic numbers for the first 26 elements.

# %% [markdown]
# 7. The following equation defines the relationship between energy (J) of a photo and its wavelength (m) where h is Plank's constant (6.626 $\times \, 10^{-34} J\cdot s$) and c is the speed of light in a vacuum (2.998 $\times \, 10^8 m/s$).
#
# $$ E = \frac{hc}{\lambda} $$

# %% [markdown]
# 8. Generate an array containing 101.325 a hundred times.

# %% [markdown]
# 9. The following array contains temperatures in Fahrenheit. Convert these values to $^\circ$C without using a for loop.
#
#     F = array([0, 32, 100, 212, 451])

# %%
T_f = np.array([0, 32, 100, 212, 451])

# %% [markdown]
# 10. Generate two arrays containing the following sine functionsfrom x = 0 $\rightarrow 10 \pi$
#
# $$ y = sin(x) $$
# $$ y = sin(1.1x + 0.5) $$
#
# a. Plot these two sine waves on the same plot.

# %% [markdown]
# b. Add the two sine functions together and plot the result.

# %% [markdown]
# c. Explain why the signal in part b is smaller in the center and larger on both ends. *Hint:* look at your plot for part a to see how the two origonal sine waves related to each other.

# %% [markdown]
# The two singals are in phases on the sides resulting in constructive interference while they are out of phase in the center resulting in destructive interference.

# %% [markdown]
# 11. The numerical relationship between ΔGo and K (equilibrium constant) is shown below. Plot ΔGo versus K at standard temperature and pressure for K values of 0.001 → 1000. Use NumPy arrays and do not use any for loops.
#
# $$ \Delta G = -RTln(k) $$

# %% [markdown]
# 12. The numerical relationship between k (rate constant) and Ea is shown below. Plot k versus Ea at standard temperature and pressure for activation energies of 1 → 20 kJ/mol. Use NumPy arrays, do not use any for loops, and use A = 1. Watch your energy units carefully.
#
# $$ k = Ae^{-E_a / RT} $$
